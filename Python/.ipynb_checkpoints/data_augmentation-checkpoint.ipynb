# %% [markdown]
# # The purpose of this script to generate test and train dataset with augmentation, as well as their labels in csv files

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Nov  4 23:20:16 2019

@author: Tomas Latysovic
"""
from data_aug.data_aug import *
from data_aug.bbox_util import *
import numpy as np 
import matplotlib.pyplot as plt 
import pickle as pkl
import glob
from PIL import Image
import os
import pandas as pd
import cv2
import random
from sklearn.model_selection import GroupShuffleSplit
pd.options.mode.chained_assignment = None  # default='warn'
model_code = "model"
img_ext = ".jpg"
# %matplotlib inline

# Replace label to sign names and save to csv (model1)
d = {0 : "speed limit 20", #
1 : "speed limit 30",
2 : "speed limit 50",
3 : "speed limit 60",
4 : "speed limit 70",
5 : "speed limit 80",
6 : "restriction ends 80", #
7 : "speed limit 100",
8 : "speed limit 120",
9 : "no overtaking",
10 : "no overtaking trucks",
11 : "priority at next intersection",
12 : "priority road",
13 : "give way",
14 : "stop",
15 : "no traffic both ways",
16 : "no trucks",
17 : "no entry",
18 : "danger",
19 : "bend left",
20 : "bend right",
21 : "bend",
22 : "uneven road",
23 : "slippery road",
24 : "road narrows",
25 : "construction",
26 : "traffic signal",
27 : "pedestrian crossing",
28 : "school crossing", #
29 : "cycles crossing",
30 : "snow",
31 : "animals",
32 : "restriction ends", #
33 : "go right",
34 : "go left",
35 : "go straight",
36 : "go right or straight",
37 : "go left or straight",
38 : "keep right",
39 : "keep left",
40 : "roundabout",
41 : "restriction ends overtaking",
42 : "restriction ends overtaking trucks"}


class_cat = {0: "prohibitory", #
1 : "prohibitory",
2 : "prohibitory",
3 : "prohibitory",
4 : "prohibitory",
5 : "prohibitory",
6 : "other", #
7 : "prohibitory",
8 : "prohibitory",
9 : "prohibitory",
10 : "prohibitory",
11 : "danger",
12 : "other",
13 : "other",
14 : "other",
15 : "prohibitory",
16 : "prohibitory",
17 : "other",
18 : "danger",
19 : "danger",
20 : "danger",
21 : "danger",
22 : "danger",
23 : "danger",
24 : "danger",
25 : "danger",
26 : "danger",
27 : "danger",
28 : "danger", #
29 : "danger",
30 : "danger",
31 : "danger",
32 : "other", #
33 : "mandatory",
34 : "mandatory",
35 : "mandatory",
36 : "mandatory",
37 : "mandatory",
38 : "mandatory",
39 : "mandatory",
40 : "mandatory",
41 : "other",
42 : "other"}

cat_class = {
    "prohibitory":0,
    "mandatory":1,
    "danger":2,
    "other":3
}


inv_d = {v: k for k, v in d.items()} # model1
class_to_four_categories = {v: k for k, v in cat_class.items()} # model1

# %%
if not(os.path.isdir("dataset/"+model_code)):
    os.mkdir("dataset/"+model_code)

mainFolder = "dataset/FullIJCNN2013/"
with open(mainFolder + "gt.txt", 'r') as f:
    file = f.readlines()
    file = [value.strip().split(';')  for value in file]
    df = pd.DataFrame(file)


df_copy = df.copy()
df_copy["height"] = 800
df_copy["width"] = 1360
cols = df_copy.columns.tolist()
print(cols)
df_copy = df_copy[[0, "width", 'height', 5, 1,2,3,4]]
df_copy = df_copy.rename({0: 'filename',\
                          5: 'class', 1: 'xmin', 2: 'ymin', 3: 'xmax', 4: 'ymax'}, axis=1)
print(df_copy.head(10))
# Out:
# [0, 1, 2, 3, 4, 5, 'height', 'width']
#     filename  width  height class xmin ymin  xmax ymax
# 0  00000.ppm   1360     800    11  774  411   815  446
# 1  00001.ppm   1360     800    40  983  388  1024  432
# 2  00001.ppm   1360     800    38  386  494   442  552
# 3  00001.ppm   1360     800    13  973  335  1031  390
# 4  00002.ppm   1360     800    39  892  476  1006  592
# 5  00003.ppm   1360     800     4  742  443   765  466
# 6  00003.ppm   1360     800     9  742  466   764  489
# 7  00003.ppm   1360     800    21  737  412   769  443
# 8  00004.ppm   1360     800    21  898  342   967  409
# 9  00004.ppm   1360     800     2  906  407   955  459

# %%
# Check class distribution
df_copy["class"].value_counts().sum()
# Out:
# 1213

# %%
if not(os.path.isdir("dataset/"+model_code+"/train")):
    os.mkdir("dataset/"+model_code+"/train")
if not(os.path.isdir("dataset/"+model_code+"/test")):
    os.mkdir("dataset/"+model_code+"/test")
    
if not(os.path.isdir("dataset/"+model_code+"/train_aug")):
    os.mkdir("dataset/"+model_code+"/train_aug")
if not(os.path.isdir("dataset/"+model_code+"/negative_images")):
    os.mkdir("dataset/"+model_code+"/negative_images")

# %%
u = df[0].unique().tolist()
file_list = sorted(glob.glob("dataset/FullIJCNN2013/*.ppm"))
filenames = []
for i in file_list:
    filenames.append(str(i.split("\\")[1]))
negative_images = set(filenames) - set (u)

for file_name in negative_images:
    name = file_name.split(".")[0]
    # Read image
    img = cv2.imread("dataset/"+"FullIJCNN2013/"+file_name)
    img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    # save
    cv2.imwrite("dataset/"+model_code+"/negative_images/"+ name + img_ext, cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR))

# %%
not_empty=True
seed=0
while not_empty:
    train_inds, test_inds = next(GroupShuffleSplit(test_size=0.3, n_splits=1,\
                                                   random_state = seed).split(df_copy,\
                                                    groups=df_copy['filename']))
    train = df_copy.iloc[train_inds]
    test = df_copy.iloc[test_inds]
    


    # Train test split

    train_list_names = train["filename"].unique().tolist()
    test_list_names = test["filename"].unique().tolist()

    df_test = df_copy.loc[df_copy["filename"].isin(test_list_names)]
    df_train = df_copy.loc[df_copy["filename"].isin(train_list_names)]

    df_test["class"] = df_test["class"].astype(int)
    df_train["class"] = df_train["class"].astype(int)



    dataset_dif = set(df_train["class"]) - set(df_test["class"])
    dataset_dif_from_test = set(df_test["class"]) - set(df_train["class"])
    print("train-test ", dataset_dif, len(dataset_dif))
    print("test-train ", dataset_dif_from_test, len(dataset_dif_from_test))


    if (len(dataset_dif) == 0) and (len(dataset_dif_from_test) == 0):
        not_empty=False
    else:
        seed+=1
# Out:
# sum os signs:  1213
# train-test  {19, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {41, 27, 39, 31} 4
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 37, 31} 3
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0, 27, 37} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 32, 39, 19, 29} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {16, 20, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 19, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {16, 36, 39, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 37, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 19, 20, 37} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {31} 1
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 37} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 37, 19, 29} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {29, 21} 2
# test-train  {19, 37} 2
# sum os signs:  1213
# train-test  {16, 37, 19, 21} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 19} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 21} 2
# test-train  {24, 31} 2
# sum os signs:  1213
# train-test  {29, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  set() 0
# test-train  {31} 1
# sum os signs:  1213
# train-test  {19, 21, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {42, 19} 2
# test-train  {27} 1
# sum os signs:  1213
# train-test  {19, 37, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 41, 34, 19} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 41, 19, 26, 27, 29} 6
# test-train  {31} 1
# sum os signs:  1213
# train-test  {39, 27, 37, 31} 4
# test-train  {19} 1
# sum os signs:  1213
# train-test  {16, 24, 19} 3
# test-train  {31} 1
# sum os signs:  1213
# train-test  {27, 30, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 39, 40, 41, 16} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {16, 19, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 39, 41, 19, 21, 31} 6
# test-train  {37} 1
# sum os signs:  1213
# train-test  {33, 36, 37, 19, 20, 30} 6
# test-train  {24, 31} 2
# sum os signs:  1213
# train-test  {27, 37, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {39, 21, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 41, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {19} 1
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 29, 39} 3
# test-train  {27} 1
# sum os signs:  1213
# train-test  {0, 32} 2
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0, 37, 39, 19, 27, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 19, 20, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 37, 39} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 20, 39, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 37, 29} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 37} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {16, 32, 27, 37} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 41, 16, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 19, 24, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 37, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 40, 41, 19, 24, 27, 31} 7
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 41, 27} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 27} 2
# test-train  {31} 1
# sum os signs:  1213
# train-test  {37, 29, 19, 21} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 31} 2
# test-train  {19} 1
# sum os signs:  1213
# train-test  {36, 37, 19, 20, 21, 27, 31} 7
# test-train  set() 0
# sum os signs:  1213
# train-test  {39, 16, 24, 27, 31} 5
# test-train  {19, 37} 2
# sum os signs:  1213
# train-test  {37, 39} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 27, 32, 19} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {19} 1
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 29} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 27, 37} 3
# test-train  {31} 1
# sum os signs:  1213
# train-test  {37, 42, 19, 27, 30, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 27, 29} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 19, 20, 29, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 37, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 32, 19, 37} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 19, 29, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 16, 27, 31} 4
# test-train  {19} 1
# sum os signs:  1213
# train-test  {19, 20} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 32, 37, 39} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 27, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 39, 41, 27, 29, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 19} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {16, 37, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 32, 37, 21} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 21} 2
# test-train  {31} 1
# sum os signs:  1213
# train-test  {37, 39, 19, 20, 22, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 16, 19, 37} 4
# test-train  {31} 1
# sum os signs:  1213
# train-test  {37, 19, 21, 24, 28, 29, 31} 7
# test-train  set() 0
# sum os signs:  1213
# train-test  {39, 37, 29, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 32, 19, 30} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 39, 21, 29, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 24, 19, 20} 4
# test-train  {37, 31} 2
# sum os signs:  1213
# train-test  {21, 31} 2
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0} 1
# test-train  {19} 1
# sum os signs:  1213
# train-test  {19, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 21, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 27, 29, 31} 4
# test-train  {19} 1
# sum os signs:  1213
# train-test  {19, 37, 22, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {16, 40, 19, 31} 4
# test-train  {37} 1
# sum os signs:  1213
# train-test  {0, 19, 37} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 19, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 39, 21, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {37} 1
# test-train  set() 0
# sum os signs:  1213
# train-test  {41, 20, 30, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 41, 19, 20, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 32, 19} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 19, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 19, 37} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 29} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 31} 2
# test-train  {19} 1
# sum os signs:  1213
# train-test  {41, 37, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 19, 21, 31} 4
# test-train  {37} 1
# sum os signs:  1213
# train-test  {0, 32, 34, 39, 16, 29} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 37} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {41, 19, 39, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 24, 21, 31} 4
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0, 24, 27, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 24, 27, 29, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 19, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {19} 1
# test-train  {37} 1
# sum os signs:  1213
# train-test  {37, 6, 39, 19, 29} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {20, 15} 2
# test-train  {37} 1
# sum os signs:  1213
# train-test  {42, 37, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 19, 29, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 37, 19, 24, 29, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 39, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {39, 27, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {39, 31} 2
# test-train  {37} 1
# sum os signs:  1213
# train-test  {41, 42, 24, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 31} 2
# test-train  {37} 1
# sum os signs:  1213
# train-test  {19, 20, 6, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 24, 19, 27} 4
# test-train  {37} 1
# sum os signs:  1213
# train-test  {0, 37, 16, 20, 27, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 32, 19, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 19, 37} 3
# test-train  {31} 1
# sum os signs:  1213
# train-test  {24, 37} 2
# test-train  {19} 1
# sum os signs:  1213
# train-test  {24, 19, 37} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 37, 31} 3
# test-train  {19} 1
# sum os signs:  1213
# train-test  {40, 19, 20, 37} 4
# test-train  {31} 1
# sum os signs:  1213
# train-test  {37, 29, 15} 3
# test-train  {19} 1
# sum os signs:  1213
# train-test  {37, 39, 19, 21, 27} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {40, 41, 19} 3
# test-train  {37} 1
# sum os signs:  1213
# train-test  set() 0
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0, 19, 39, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {42, 19, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {16, 41, 32, 22} 4
# test-train  {37} 1
# sum os signs:  1213
# train-test  {37, 15} 2
# test-train  {31} 1
# sum os signs:  1213
# train-test  {32, 42, 19, 21, 31} 5
# test-train  {37} 1
# sum os signs:  1213
# train-test  {37, 22, 39} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 27, 37, 39} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {39, 19, 21, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 29, 39} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 27, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 37, 29} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 19, 21, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 27, 19, 37} 4
# test-train  {29} 1
# sum os signs:  1213
# train-test  {39, 19, 37, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {32} 1
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 37, 6, 16, 19, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 39, 19, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {34, 37, 20, 24, 28} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 41, 32, 37} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 39, 19, 21, 27} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 37, 19, 21} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 37, 39, 27, 31} 5
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0, 32, 37, 19, 21} 5
# test-train  {31} 1
# sum os signs:  1213
# train-test  {24, 20, 21} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {20, 31} 2
# test-train  {27} 1
# sum os signs:  1213
# train-test  {24, 32, 21} 3
# test-train  {37, 29} 2
# sum os signs:  1213
# train-test  {0, 37, 19, 24, 27} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 27} 2
# test-train  {37} 1
# sum os signs:  1213
# train-test  {0, 34, 26, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 27} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 37} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 27, 19} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 29, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 36, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {42, 39} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 19, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 6, 19, 20, 21, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 39, 19, 29, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 31} 2
# test-train  {37} 1
# sum os signs:  1213
# train-test  {37, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 32, 20, 39} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 20, 29} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {39, 37, 15} 3
# test-train  {31} 1
# sum os signs:  1213
# train-test  {37, 41, 19, 29, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 39} 2
# test-train  {37} 1
# sum os signs:  1213
# train-test  {31} 1
# test-train  {19} 1
# sum os signs:  1213
# train-test  {37, 31} 2
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0, 6, 16, 19, 27} 5
# test-train  {24} 1
# sum os signs:  1213
# train-test  {0, 34, 27, 31} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {32, 20, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 20, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {39} 1
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 19, 37} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 19, 20, 37} 4
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 31} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {39, 19, 24, 27, 29, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 39, 41, 19, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {20, 37, 31} 3
# test-train  {27} 1
# sum os signs:  1213
# train-test  {0, 19, 21} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 37} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {21, 6} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {24, 37} 2
# test-train  {19} 1
# sum os signs:  1213
# train-test  {32, 19, 37} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {19, 31} 2
# test-train  {37} 1
# sum os signs:  1213
# train-test  {0, 37, 39, 20, 27, 31} 6
# test-train  {19} 1
# sum os signs:  1213
# train-test  {39, 41, 16, 19, 27, 29, 31} 7
# test-train  set() 0
# sum os signs:  1213
# train-test  {16, 39, 37, 31} 4
# test-train  {19} 1
# sum os signs:  1213
# train-test  {32, 41, 31} 3
# test-train  {19, 37} 2
# sum os signs:  1213
# train-test  {16} 1
# test-train  {27} 1
# sum os signs:  1213
# train-test  {0, 41, 24, 27, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {0, 27, 19} 3
# test-train  {37} 1
# sum os signs:  1213
# train-test  set() 0
# test-train  {19} 1
# sum os signs:  1213
# train-test  {16, 19, 20, 29, 31} 5
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 29, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  set() 0
# test-train  {37} 1
# sum os signs:  1213
# train-test  {0, 19, 21} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {37, 21} 2
# test-train  {19} 1
# sum os signs:  1213
# train-test  {0, 37, 16, 19, 21, 31} 6
# test-train  set() 0
# sum os signs:  1213
# train-test  {27, 29} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  {37} 1
# test-train  {27} 1
# sum os signs:  1213
# train-test  {24, 19, 31} 3
# test-train  set() 0
# sum os signs:  1213
# train-test  {41, 19} 2
# test-train  set() 0
# sum os signs:  1213
# train-test  set() 0
# test-train  set() 0

# %%
print(df_test.dtypes, "\n")
print(df_train.dtypes)
# Out:
# filename    object
# width        int64
# height       int64
# class        int32
# xmin        object
# ymin        object
# xmax        object
# ymax        object
# dtype: object
#
# filename    object
# width        int64
# height       int64
# class        int32
# xmin        object
# ymin        object
# xmax        object
# ymax        object
# dtype: object
# 0       00000.ppm
# 1       00001.ppm
# 2       00001.ppm
# 3       00001.ppm
# 5       00003.ppm
#           ...
# 1207    00895.ppm
# 1208    00896.ppm
# 1209    00897.ppm
# 1210    00898.ppm
# 1211    00898.ppm
# Name: filename, Length: 856, dtype: object

# %%
import imgaug as ia
import imgaug.augmenters as iaa
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage
ia.seed(1)

GREEN = [0, 255, 0]
ORANGE = [255, 140, 0]
RED = [255, 0, 0]
# df_test["filename"] = df_test["filename"].str.replace('.ppm','.png')
# df_train["filename"] = df_train["filename"].str.replace('.ppm','.png')
# df_test.replace({"class": d}, inplace = True)
# df_train.replace({"class": d}, inplace = True)
cols=df_copy.columns.tolist()
df_train_labels = pd.DataFrame(columns=cols)
df_test_labels = pd.DataFrame(columns=cols)
df_train_labels_aug = pd.DataFrame(columns=cols)
print(cols)
print(model_code)
# Out:
# ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
# model3

# %%
split = True
isresize = False
if split: 
    print("Splitting actual images...")  
    for idx, file_name in enumerate(test_list_names):
        name = file_name.split(".")[0]
        print("Name in test set", name)
        # Read image
        img = cv2.imread("dataset/"+"FullIJCNN2013/"+file_name)
        img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        bboxes = df_test[df_test["filename"]==file_name][["xmin", "ymin", "xmax", "ymax", "class"]].astype(float).values
        
        if isresize == True:
            # Resizing original
            img_, bboxes_ = Resize(300)(img_rgb.copy(), bboxes.copy())
            bboxes_ = np.round(bboxes_, 0).astype(int)
        else:
            img_, bboxes_ = img_rgb.copy(), bboxes.copy()
        
        # save image
        height, width, channels = img_.shape
        for bb in bboxes_:
            df_test_labels = df_test_labels.append({'filename':name+img_ext, 'width':width,
                                                'height':height, 'class':bb[:][-1], 'xmin':bb[:][0],
                                                    'ymin':bb[:][1], 'xmax':bb[:][2], 'ymax':bb[:][3]}, ignore_index=True)
        cv2.imwrite("dataset/"+model_code+"/test/"+ name + img_ext, cv2.cvtColor(img_, cv2.COLOR_RGB2BGR))
    


    for idx, file_name in enumerate(train_list_names): # train_list_names
        name = file_name.split(".")[0]
        print("Name in train set", name)
        
        
        # Read image
        img = cv2.imread("dataset/"+"FullIJCNN2013/"+file_name)
        img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        bboxes = df_train[df_train["filename"]==file_name][["xmin", "ymin", "xmax", "ymax", "class"]].astype(float).values
        
        
        
        if isresize == True:
            # Resizing original
            img_, bboxes_ = Resize(300)(img_rgb.copy(), bboxes.copy())
            bboxes_ = np.round(bboxes_, 0).astype(int)
        else:
            img_, bboxes_ = img_rgb.copy(), bboxes.copy()
        
            
        # save image
        height, width, channels = img_.shape
        for bb in bboxes_:
            df_train_labels = df_train_labels.append({'filename':name+img_ext, 'width':width,
                                                'height':height, 'class':bb[:][-1], 'xmin':bb[:][0],
                                                    'ymin':bb[:][1], 'xmax':bb[:][2], 'ymax':bb[:][3]}, ignore_index=True)
            df_train_labels_aug = df_train_labels_aug.append({'filename':name+img_ext, 'width':width,
                                                'height':height, 'class':bb[:][-1], 'xmin':bb[:][0],
                                                    'ymin':bb[:][1], 'xmax':bb[:][2], 'ymax':bb[:][3]}, ignore_index=True)
            
        cv2.imwrite("dataset/"+model_code+"/train/"+ name + img_ext, cv2.cvtColor(img_, cv2.COLOR_RGB2BGR))
        cv2.imwrite("dataset/"+model_code+"/train_aug/"+ name + img_ext, cv2.cvtColor(img_, cv2.COLOR_RGB2BGR))
           
            
        
        # Sequence 1
        result = False
        while result == False:
            try:
                if isresize == True:
                    seq = Sequence([RandomHSV(hue = 30, saturation = 30, brightness = 20),
                                RandomScale(0.15, diff = False), RandomTranslate(0.15, diff = False), RandomRotate(angle = 5),
                                RandomShear(shear_factor = 0.15), Resize(300)])
                else:
                    seq = Sequence([RandomHSV(hue = 30, saturation = 30, brightness = 20),
                                RandomScale(0.15, diff = False), RandomTranslate(0.15, diff = False), RandomRotate(angle = 5),
                                RandomShear(shear_factor = 0.15)])                    

                img_, bboxes_ = seq(img_rgb.copy(), bboxes.copy())
                result = True
            except:
                result =  False
        

        bboxes_ = np.round(bboxes_, 0).astype(int)
        # save image
        height, width, channels = img_.shape

        for bb in bboxes_:
            df_train_labels_aug = df_train_labels_aug.append({'filename':name+"a"+img_ext, 'width':width,
                                                'height':height, 'class':bb[:][-1], 'xmin':bb[:][0],
                                                    'ymin':bb[:][1], 'xmax':bb[:][2], 'ymax':bb[:][3]}, ignore_index=True)
            
        cv2.imwrite("dataset/"+model_code+"/train_aug/"+ name + "a"+img_ext, cv2.cvtColor(img_, cv2.COLOR_RGB2BGR))
         
        if isresize == True:
            # Sequence 2
            result = False
            while result == False:
                try:
                    seq = Sequence([RandomHSV(hue=30, saturation=30, brightness=25), RandomExpand(0.5), RandomCrop(1), Resize(300)])                
                    img_, bboxes_ = seq(img_rgb.copy(), bboxes.copy())
                    result = True
                except:
                    result =  False
            bboxes_ = np.round(bboxes_, 0).astype(int)
            # save image
            height, width, channels = img_.shape
            for bb in bboxes_:
                df_train_labels = df_train_labels.append({'filename':name+"b"+img_ext, 'width':width,
                                                    'height':height, 'class':bb[:][-1], 'xmin':bb[:][0],
                                                        'ymin':bb[:][1], 'xmax':bb[:][2], 'ymax':bb[:][3]}, ignore_index=True)
            cv2.imwrite("dataset/"+model_code+"/train/"+ name + "b"+img_ext, cv2.cvtColor(img_, cv2.COLOR_RGB2BGR))
# Out:
# Splitting actual images...
# Name in test set 00002
# Name in test set 00010
# Name in test set 00016
# Name in test set 00017
# Name in test set 00018
# Name in test set 00019
# Name in test set 00020
# Name in test set 00021
# Name in test set 00025
# Name in test set 00026
# Name in test set 00027
# Name in test set 00031
# Name in test set 00034
# Name in test set 00043
# Name in test set 00049
# Name in test set 00057
# Name in test set 00059
# Name in test set 00063
# Name in test set 00067
# Name in test set 00069
# Name in test set 00075
# Name in test set 00076
# Name in test set 00077
# Name in test set 00079
# Name in test set 00080
# Name in test set 00085
# Name in test set 00090
# Name in test set 00092
# Name in test set 00096
# Name in test set 00102
# Name in test set 00103
# Name in test set 00104
# Name in test set 00105
# Name in test set 00106
# Name in test set 00111
# Name in test set 00116
# Name in test set 00117
# Name in test set 00125
# Name in test set 00129
# Name in test set 00130
# Name in test set 00133
# Name in test set 00137
# Name in test set 00141
# Name in test set 00142
# Name in test set 00147
# Name in test set 00148
# Name in test set 00149
# Name in test set 00152
# Name in test set 00155
# Name in test set 00156
# Name in test set 00158
# Name in test set 00163
# Name in test set 00164
# Name in test set 00165
# Name in test set 00166
# Name in test set 00174
# Name in test set 00177
# Name in test set 00179
# Name in test set 00180
# Name in test set 00183
# Name in test set 00187
# Name in test set 00193
# Name in test set 00196
# Name in test set 00197
# Name in test set 00202
# Name in test set 00215
# Name in test set 00217
# Name in test set 00221
# Name in test set 00224
# Name in test set 00231
# Name in test set 00233
# Name in test set 00234
# Name in test set 00236
# Name in test set 00237
# Name in test set 00239
# Name in test set 00244
# Name in test set 00249
# Name in test set 00251
# Name in test set 00254
# Name in test set 00266
# Name in test set 00269
# Name in test set 00274
# Name in test set 00276
# Name in test set 00277
# Name in test set 00279
# Name in test set 00280
# Name in test set 00285
# Name in test set 00286
# Name in test set 00289
# Name in test set 00294
# Name in test set 00295
# Name in test set 00298
# Name in test set 00299
# Name in test set 00300
# Name in test set 00302
# Name in test set 00303
# Name in test set 00306
# Name in test set 00333
# Name in test set 00334
# Name in test set 00338
# Name in test set 00339
# Name in test set 00343
# Name in test set 00346
# Name in test set 00348
# Name in test set 00360
# Name in test set 00362
# Name in test set 00376
# Name in test set 00380
# Name in test set 00382
# Name in test set 00385
# Name in test set 00388
# Name in test set 00400
# Name in test set 00401
# Name in test set 00402
# Name in test set 00411
# Name in test set 00415
# Name in test set 00418
# Name in test set 00419
# Name in test set 00427
# Name in test set 00430
# Name in test set 00434
# Name in test set 00439
# Name in test set 00441
# Name in test set 00445
# Name in test set 00448
# Name in test set 00452
# Name in test set 00456
# Name in test set 00459
# Name in test set 00466
# Name in test set 00473
# Name in test set 00474
# Name in test set 00478
# Name in test set 00484
# Name in test set 00487
# Name in test set 00491
# Name in test set 00496
# Name in test set 00497
# Name in test set 00499
# Name in test set 00500
# Name in test set 00504
# Name in test set 00520
# Name in test set 00527
# Name in test set 00528
# Name in test set 00548
# Name in test set 00554
# Name in test set 00566
# Name in test set 00567
# Name in test set 00602
# Name in test set 00603
# Name in test set 00605
# Name in test set 00607
# Name in test set 00609
# Name in test set 00616
# Name in test set 00630
# Name in test set 00637
# Name in test set 00640
# Name in test set 00650
# Name in test set 00657
# Name in test set 00659
# Name in test set 00661
# Name in test set 00665
# Name in test set 00669
# Name in test set 00670
# Name in test set 00671
# Name in test set 00672
# Name in test set 00674
# Name in test set 00690
# Name in test set 00691
# Name in test set 00696
# Name in test set 00702
# Name in test set 00703
# Name in test set 00705
# Name in test set 00707
# Name in test set 00710
# Name in test set 00717
# Name in test set 00723
# Name in test set 00728
# Name in test set 00730
# Name in test set 00734
# Name in test set 00744
# Name in test set 00754
# Name in test set 00755
# Name in test set 00762
# Name in test set 00763
# Name in test set 00770
# Name in test set 00776
# Name in test set 00778
# Name in test set 00780
# Name in test set 00782
# Name in test set 00784
# Name in test set 00787
# Name in test set 00789
# Name in test set 00791
# Name in test set 00794
# Name in test set 00802
# Name in test set 00803
# Name in test set 00807
# Name in test set 00817
# Name in test set 00824
# Name in test set 00825
# Name in test set 00827
# Name in test set 00831
# Name in test set 00835
# Name in test set 00838
# Name in test set 00839
# Name in test set 00842
# Name in test set 00846
# Name in test set 00848
# Name in test set 00849
# Name in test set 00851
# Name in test set 00855
# Name in test set 00857
# Name in test set 00859
# Name in test set 00868
# Name in test set 00869
# Name in test set 00871
# Name in test set 00874
# Name in test set 00876
# Name in test set 00882
# Name in test set 00885
# Name in test set 00891
# Name in test set 00893
# Name in test set 00899
# Name in train set 00000
# Name in train set 00001
# Name in train set 00003
# Name in train set 00004
# Name in train set 00005
# Name in train set 00006
# Name in train set 00007
# Name in train set 00008
# Name in train set 00009
# Name in train set 00011
# Name in train set 00012
# Name in train set 00013
# Name in train set 00014
# Name in train set 00015
# Name in train set 00022
# Name in train set 00023
# Name in train set 00024
# Name in train set 00028
# Name in train set 00029
# Name in train set 00030
# Name in train set 00032
# Name in train set 00033
# Name in train set 00035
# Name in train set 00036
# Name in train set 00037
# Name in train set 00038
# Name in train set 00039
# Name in train set 00040
# Name in train set 00041
# Name in train set 00042
# Name in train set 00044
# Name in train set 00045
# Name in train set 00046
# Name in train set 00047
# Name in train set 00048
# Name in train set 00050
# Name in train set 00051
# Name in train set 00052
# Name in train set 00053
# Name in train set 00054
# Name in train set 00055
# Name in train set 00056
# Name in train set 00058
# Name in train set 00060
# Name in train set 00061
# Name in train set 00062
# Name in train set 00064
# Name in train set 00065
# Name in train set 00066
# Name in train set 00068
# Name in train set 00070
# Name in train set 00071
# Name in train set 00072
# Name in train set 00073
# Name in train set 00074
# Name in train set 00078
# Name in train set 00081
# Name in train set 00082
# Name in train set 00083
# Name in train set 00084
# Name in train set 00086
# Name in train set 00087
# Name in train set 00088
# Name in train set 00089
# Name in train set 00091
# Name in train set 00093
# Name in train set 00094
# Name in train set 00095
# Name in train set 00097
# Name in train set 00098
# Name in train set 00099
# Name in train set 00100
# Name in train set 00101
# Name in train set 00107
# Name in train set 00109
# Name in train set 00110
# Name in train set 00112
# Name in train set 00113
# Name in train set 00114
# Name in train set 00115
# Name in train set 00118
# Name in train set 00119
# Name in train set 00120
# Name in train set 00121
# Name in train set 00122
# Name in train set 00123
# Name in train set 00124
# Name in train set 00126
# Name in train set 00127
# Name in train set 00128
# Name in train set 00131
# Name in train set 00132
# Name in train set 00134
# Name in train set 00135
# Name in train set 00136
# Name in train set 00138
# Name in train set 00140
# Name in train set 00143
# Name in train set 00144
# Name in train set 00146
# Name in train set 00150
# Name in train set 00151
# Name in train set 00153
# Name in train set 00154
# Name in train set 00157
# Name in train set 00159
# Name in train set 00160
# Name in train set 00161
# Name in train set 00162
# Name in train set 00167
# Name in train set 00168
# Name in train set 00169
# Name in train set 00170
# Name in train set 00171
# Name in train set 00172
# Name in train set 00173
# Name in train set 00175
# Name in train set 00176
# Name in train set 00178
# Name in train set 00181
# Name in train set 00182
# Name in train set 00184
# Name in train set 00185
# Name in train set 00186
# Name in train set 00188
# Name in train set 00189
# Name in train set 00190
# Name in train set 00191
# Name in train set 00192
# Name in train set 00194
# Name in train set 00195
# Name in train set 00198
# Name in train set 00199
# Name in train set 00200
# Name in train set 00201
# Name in train set 00203
# Name in train set 00204
# Name in train set 00205
# Name in train set 00206
# Name in train set 00207
# Name in train set 00208
# Name in train set 00209
# Name in train set 00210
# Name in train set 00211
# Name in train set 00212
# Name in train set 00214
# Name in train set 00216
# Name in train set 00218
# Name in train set 00219
# Name in train set 00220
# Name in train set 00222
# Name in train set 00223
# Name in train set 00225
# Name in train set 00226
# Name in train set 00227
# Name in train set 00228
# Name in train set 00229
# Name in train set 00230
# Name in train set 00232
# Name in train set 00238
# Name in train set 00240
# Name in train set 00241
# Name in train set 00242
# Name in train set 00243
# Name in train set 00245
# Name in train set 00246
# Name in train set 00247
# Name in train set 00248
# Name in train set 00250
# Name in train set 00252
# Name in train set 00253
# Name in train set 00255
# Name in train set 00256
# Name in train set 00257
# Name in train set 00258
# Name in train set 00259
# Name in train set 00260
# Name in train set 00261
# Name in train set 00262
# Name in train set 00263
# Name in train set 00264
# Name in train set 00265
# Name in train set 00267
# Name in train set 00268
# Name in train set 00270
# Name in train set 00271
# Name in train set 00272
# Name in train set 00273
# Name in train set 00275
# Name in train set 00278
# Name in train set 00281
# Name in train set 00282
# Name in train set 00283
# Name in train set 00284
# Name in train set 00287
# Name in train set 00288
# Name in train set 00290
# Name in train set 00291
# Name in train set 00292
# Name in train set 00293
# Name in train set 00296
# Name in train set 00297
# Name in train set 00301
# Name in train set 00304
# Name in train set 00305
# Name in train set 00307
# Name in train set 00309
# Name in train set 00310
# Name in train set 00311
# Name in train set 00312
# Name in train set 00313
# Name in train set 00314
# Name in train set 00315
# Name in train set 00316
# Name in train set 00317
# Name in train set 00318
# Name in train set 00319
# Name in train set 00320
# Name in train set 00322
# Name in train set 00323
# Name in train set 00330
# Name in train set 00337
# Name in train set 00340
# Name in train set 00341
# Name in train set 00344
# Name in train set 00347
# Name in train set 00349
# Name in train set 00350
# Name in train set 00351
# Name in train set 00352
# Name in train set 00353
# Name in train set 00355
# Name in train set 00356
# Name in train set 00357
# Name in train set 00358
# Name in train set 00359
# Name in train set 00363
# Name in train set 00366
# Name in train set 00367
# Name in train set 00368
# Name in train set 00369
# Name in train set 00370
# Name in train set 00371
# Name in train set 00372
# Name in train set 00373
# Name in train set 00374
# Name in train set 00375
# Name in train set 00377
# Name in train set 00378
# Name in train set 00379
# Name in train set 00383
# Name in train set 00384
# Name in train set 00386
# Name in train set 00387
# Name in train set 00390
# Name in train set 00391
# Name in train set 00392
# Name in train set 00393
# Name in train set 00395
# Name in train set 00396
# Name in train set 00397
# Name in train set 00398
# Name in train set 00403
# Name in train set 00404
# Name in train set 00405
# Name in train set 00406
# Name in train set 00408
# Name in train set 00410
# Name in train set 00412
# Name in train set 00413
# Name in train set 00414
# Name in train set 00416
# Name in train set 00417
# Name in train set 00420
# Name in train set 00421
# Name in train set 00422
# Name in train set 00423
# Name in train set 00425
# Name in train set 00426
# Name in train set 00428
# Name in train set 00431
# Name in train set 00432
# Name in train set 00433
# Name in train set 00435
# Name in train set 00436
# Name in train set 00438
# Name in train set 00440
# Name in train set 00443
# Name in train set 00444
# Name in train set 00446
# Name in train set 00447
# Name in train set 00449
# Name in train set 00450
# Name in train set 00451
# Name in train set 00453
# Name in train set 00455
# Name in train set 00457
# Name in train set 00458
# Name in train set 00460
# Name in train set 00461
# Name in train set 00463
# Name in train set 00465
# Name in train set 00467
# Name in train set 00468
# Name in train set 00470
# Name in train set 00471
# Name in train set 00472
# Name in train set 00475
# Name in train set 00476
# Name in train set 00477
# Name in train set 00479
# Name in train set 00480
# Name in train set 00481
# Name in train set 00482
# Name in train set 00483
# Name in train set 00485
# Name in train set 00486
# Name in train set 00488
# Name in train set 00490
# Name in train set 00492
# Name in train set 00493
# Name in train set 00494
# Name in train set 00498
# Name in train set 00501
# Name in train set 00502
# Name in train set 00503
# Name in train set 00505
# Name in train set 00507
# Name in train set 00508
# Name in train set 00509
# Name in train set 00512
# Name in train set 00513
# Name in train set 00514
# Name in train set 00515
# Name in train set 00516
# Name in train set 00517
# Name in train set 00518
# Name in train set 00519
# Name in train set 00521
# Name in train set 00523
# Name in train set 00524
# Name in train set 00530
# Name in train set 00531
# Name in train set 00536
# Name in train set 00542
# Name in train set 00544
# Name in train set 00545
# Name in train set 00551
# Name in train set 00552
# Name in train set 00556
# Name in train set 00557
# Name in train set 00560
# Name in train set 00564
# Name in train set 00565
# Name in train set 00570
# Name in train set 00571
# Name in train set 00575
# Name in train set 00593
# Name in train set 00599
# Name in train set 00601
# Name in train set 00604
# Name in train set 00606
# Name in train set 00608
# Name in train set 00610
# Name in train set 00611
# Name in train set 00612
# Name in train set 00613
# Name in train set 00615
# Name in train set 00619
# Name in train set 00620
# Name in train set 00621
# Name in train set 00622
# Name in train set 00623
# Name in train set 00624
# Name in train set 00625
# Name in train set 00626
# Name in train set 00628
# Name in train set 00631
# Name in train set 00632
# Name in train set 00633
# Name in train set 00634
# Name in train set 00635
# Name in train set 00638
# Name in train set 00639
# Name in train set 00641
# Name in train set 00642
# Name in train set 00644
# Name in train set 00645
# Name in train set 00646
# Name in train set 00647
# Name in train set 00648
# Name in train set 00649
# Name in train set 00651
# Name in train set 00653
# Name in train set 00654
# Name in train set 00655
# Name in train set 00656
# Name in train set 00658
# Name in train set 00660
# Name in train set 00662
# Name in train set 00663
# Name in train set 00664
# Name in train set 00667
# Name in train set 00668
# Name in train set 00673
# Name in train set 00675
# Name in train set 00678
# Name in train set 00679
# Name in train set 00680
# Name in train set 00681
# Name in train set 00682
# Name in train set 00683
# Name in train set 00685
# Name in train set 00686
# Name in train set 00688
# Name in train set 00689
# Name in train set 00692
# Name in train set 00693
# Name in train set 00694
# Name in train set 00695
# Name in train set 00697
# Name in train set 00698
# Name in train set 00699
# Name in train set 00700
# Name in train set 00701
# Name in train set 00704
# Name in train set 00706
# Name in train set 00712
# Name in train set 00714
# Name in train set 00715
# Name in train set 00716
# Name in train set 00719
# Name in train set 00720
# Name in train set 00721
# Name in train set 00722
# Name in train set 00725
# Name in train set 00729
# Name in train set 00732
# Name in train set 00733
# Name in train set 00736
# Name in train set 00737
# Name in train set 00738
# Name in train set 00740
# Name in train set 00741
# Name in train set 00742
# Name in train set 00746
# Name in train set 00747
# Name in train set 00749
# Name in train set 00751
# Name in train set 00752
# Name in train set 00756
# Name in train set 00758
# Name in train set 00760
# Name in train set 00761
# Name in train set 00764
# Name in train set 00766
# Name in train set 00771
# Name in train set 00772
# Name in train set 00773
# Name in train set 00774
# Name in train set 00775
# Name in train set 00777
# Name in train set 00779
# Name in train set 00783
# Name in train set 00785
# Name in train set 00788
# Name in train set 00795
# Name in train set 00797
# Name in train set 00798
# Name in train set 00801
# Name in train set 00805
# Name in train set 00806
# Name in train set 00808
# Name in train set 00809
# Name in train set 00810
# Name in train set 00811
# Name in train set 00813
# Name in train set 00816
# Name in train set 00818
# Name in train set 00820
# Name in train set 00821
# Name in train set 00822
# Name in train set 00823
# Name in train set 00828
# Name in train set 00829
# Name in train set 00833
# Name in train set 00834
# Name in train set 00836
# Name in train set 00837
# Name in train set 00841
# Name in train set 00844
# Name in train set 00845
# Name in train set 00850
# Name in train set 00852
# Name in train set 00853
# Name in train set 00854
# Name in train set 00858
# Name in train set 00860
# Name in train set 00862
# Name in train set 00863
# Name in train set 00864
# Name in train set 00865
# Name in train set 00866
# Name in train set 00867
# Name in train set 00870
# Name in train set 00872
# Name in train set 00879
# Name in train set 00881
# Name in train set 00884
# Name in train set 00886
# Name in train set 00887
# Name in train set 00888
# Name in train set 00889
# Name in train set 00894
# Name in train set 00895
# Name in train set 00896
# Name in train set 00897
# Name in train set 00898

# %%
# df_test_labels.replace({"class": d}, inplace = True)
# df_train_labels.replace({"class": d}, inplace = True)
df_test_labels = df_test_labels.replace({"class": class_cat})
df_train_labels = df_train_labels.replace({"class": class_cat})
df_train_labels_aug = df_train_labels_aug.replace({"class": class_cat})
df_test_labels.to_csv("dataset/"+model_code+"/test_labels.csv", sep=',', encoding='utf-8', index=False)
df_train_labels.to_csv("dataset/"+model_code+"/train_labels.csv", sep=',', encoding='utf-8', index=False)
df_train_labels_aug.to_csv("dataset/"+model_code+"/train_labels_aug.csv", sep=',', encoding='utf-8', index=False)
print("Successfully created csv label files")

# Check if coordinates right
# Out:
# Successfully created csv label files

# %%
df_train_labels_aug["class"].value_counts()
# Out:
# prohibitory    790
# other          370
# danger         292
# mandatory      240
# Name: class, dtype: int64
